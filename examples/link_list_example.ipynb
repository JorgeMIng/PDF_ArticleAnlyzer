# %%
# add the local libraries to the path

import sys
from pathlib import Path
import os
print(os.getcwd())
father_path = Path(os.path.dirname(os.getcwd()))
print(father_path)
sys.path.append(os.path.join(father_path))



from util.api.visualize.links_search import LinksSearch
from config.config_search import load_config

from omegaconf import OmegaConf
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# e:\Escritorio\upm\open_science\examples
# e:\Escritorio\upm\open_science

# %%
server_config = load_config("api/grobid-server-config.yaml")
link_config = load_config("api/list_links-config.yaml")
print("SERVER_CONFIG\n"+OmegaConf.to_yaml(server_config))
print("LINK_CONFIG\n"+OmegaConf.to_yaml(link_config))
# Out:
# SERVER_CONFIG
# url:
#   protocol: http
#   api_domain: yordi111nas.synology.me
#   port: 8070
#
# LINK_CONFIG
# data:
#   data_dir: data/PDFs
#   format: .pdf
#   recursive: true
# grobid:
#   cache: true
#   cache_dir: data/xmls
#   operation_key: processFulltextDocument
#   format: .grobid.tei.xml
#   recursive: true
# list:
#   style: default
#   index:
#     justify: right
#     style: white
#   refs:
#     justify: left
#     style: white
#   html:
#     justify: left
#     style: white

# %% [markdown]
# ### Modify the config files before starting or here with code
#  For example
#
#  server_config.protocol = https

# %%
link_report = LinksSearch(link_config,server_config)
# Out:
# http://yordi111nas.synology.me:8070/api/isalive
# GROBID server is up and running
# data/xmls\nlp\Bert.grobid.tei.xml already exist, skipping... (use --force to reprocess pdf input files)
# data/xmls\nlp\Transformers.grobid.tei.xml already exist, skipping... (use --force to reprocess pdf input files)
# grobid_logger: 2024-02-11 19:32:15,710 | INFO | API.py:33 | 14436 >>> All files have been process by the api
# grobid_logger: 2024-02-11 19:32:15,788 | INFO | links_search.py:59 | 14436 >>> All links have been extracted from file Bert
# grobid_logger: 2024-02-11 19:32:15,847 | INFO | links_search.py:59 | 14436 >>> All links have been extracted from file Transformers

# %%
link_report.get_len()
# Out:
# 2

# %%
link_report.print_all_reports()
# Out:
#                                         File: Bert
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Index ┃ Links Refs                   ┃ Links Html                                      ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │     1 │ (Peters et al., 2018a;       │ https://github.com/ google-research/bert.       │
# │     2 │ Radford et al., 2018)        │ https://gluebenchmark.com/leaderboard           │
# │     3 │ Le, 2015;                    │ https://gluebenchmark.com/ leaderboard          │
# │     4 │ Peters et al., 2018a;        │ https://blog. openai.com/language-unsupervised. │
# │     5 │ Radford et al., 2018;        │                                                 │
# │     6 │ Howard and Ruder, 2018)      │                                                 │
# │     7 │ (Bowman et al., 2015;        │                                                 │
# │     8 │ Williams et al., 2018)       │                                                 │
# │     9 │ (Dolan and Brockett, 2005)   │                                                 │
# │    10 │ Sang and De Meulder, 2003;   │                                                 │
# │    11 │ Rajpurkar et al., 2016)      │                                                 │
# │    12 │ (Peters et al., 2018a)       │                                                 │
# │    13 │ (Radford et al., 2018)       │                                                 │
# │    14 │ (Vaswani et al., 2017)       │                                                 │
# │    15 │ (Taylor, 1953)               │                                                 │
# │    16 │ Radford et al. (2018)        │                                                 │
# │    17 │ Peters et al. (2018a)        │                                                 │
# │    18 │ (Brown et al., 1992;         │                                                 │
# │    19 │ Ando and Zhang, 2005;        │                                                 │
# │    20 │ Blitzer et al., 2006)        │                                                 │
# │    21 │ Pennington et al., 2014)     │                                                 │
# │    22 │ (Turian et al., 2010)        │                                                 │
# │    23 │ (Mnih and Hinton, 2009)      │                                                 │
# │    24 │ Logeswaran and Lee, 2018)    │                                                 │
# │    25 │ (Le and Mikolov, 2014)       │                                                 │
# │    26 │ (Jernite et al., 2017;       │                                                 │
# │    27 │ Logeswaran and Lee, 2018)    │                                                 │
# │    28 │ (Hill et al., 2016)          │                                                 │
# │    29 │ (Peters et al., 2017         │                                                 │
# │    30 │ (Peters et al., , 2018a      │                                                 │
# │    31 │ (Peters et al., 2018a)       │                                                 │
# │    32 │ (Rajpurkar et al., 2016)     │                                                 │
# │    33 │ (Socher et al., 2013)        │                                                 │
# │    34 │ Sang and De Meulder, 2003)   │                                                 │
# │    35 │ Melamud et al. (2016)        │                                                 │
# │    36 │ Fedus et al. (2018)          │                                                 │
# │    37 │ (Collobert and Weston, 2008) │                                                 │
# │    38 │ Le, 2015;                    │                                                 │
# │    39 │ Howard and Ruder, 2018;      │                                                 │
# │    40 │ Radford et al., 2018)        │                                                 │
# │    41 │ (Radford et al., 2018)       │                                                 │
# │    42 │ (Wang et al., 2018a)         │                                                 │
# │    43 │ (Howard and Ruder, 2018;     │                                                 │
# │    44 │ Radford et al., 2018;        │                                                 │
# │    45 │ Dai and Le, 2015)            │                                                 │
# │    46 │ (Conneau et al., 2017)       │                                                 │
# │    47 │ (McCann et al., 2017)        │                                                 │
# │    48 │ (Deng et al., 2009;          │                                                 │
# │    49 │ Yosinski et al., 2014)       │                                                 │
# │    50 │ 1                            │                                                 │
# │    51 │ Vaswani et al. (2017)        │                                                 │
# │    52 │ Vaswani et al. (2017)        │                                                 │
# │    53 │ 2                            │                                                 │
# │    54 │ 3                            │                                                 │
# │    55 │ 4                            │                                                 │
# │    56 │ (Wu et al., 2016)            │                                                 │
# │    57 │ ([CLS]                       │                                                 │
# │    58 │ ([SEP]                       │                                                 │
# │    59 │ 1                            │                                                 │
# │    60 │ 2                            │                                                 │
# │    61 │ Peters et al. (2018a)        │                                                 │
# │    62 │ Radford et al. (2018)        │                                                 │
# │    63 │ 1                            │                                                 │
# │    64 │ (Taylor, 1953)               │                                                 │
# │    65 │ (Vincent et al., 2008)       │                                                 │
# │    66 │ 1                            │                                                 │
# │    67 │ Jernite et al. (2017)        │                                                 │
# │    68 │ Logeswaran and Lee (2018)    │                                                 │
# │    69 │ (Chelba et al., 2013)        │                                                 │
# │    70 │ 2016                         │                                                 │
# │    71 │ Seo et al. (2017)            │                                                 │
# │    72 │ 7                            │                                                 │
# │    73 │ (Wang et al., 2018a          │                                                 │
# │    74 │ 9                            │                                                 │
# │    75 │ 1                            │                                                 │
# │    76 │ (Rajpurkar et al., 2016)     │                                                 │
# │    77 │ 9                            │                                                 │
# │    78 │ 1                            │                                                 │
# │    79 │ 2                            │                                                 │
# │    80 │ (Seo et al., 2017;           │                                                 │
# │    81 │ Clark and Gardner, 2018;     │                                                 │
# │    82 │ Peters et al., 2018a;        │                                                 │
# │    83 │ Hu et al., 2018)             │                                                 │
# │    84 │ (Joshi et al., 2017)         │                                                 │
# │    85 │ 12                           │                                                 │
# │    86 │ (Sun et al., 2018;           │                                                 │
# │    87 │ Wang et al., 2018b           │                                                 │
# │    88 │ 3                            │                                                 │
# │    89 │ (Zellers et al., 2018)       │                                                 │
# │    90 │ 4                            │                                                 │
# │    91 │ 5                            │                                                 │
# │    92 │ 6                            │                                                 │
# │    93 │ Vaswani et al. (2017)        │                                                 │
# │    94 │ (Al-Rfou et al., 2018)       │                                                 │
# │    95 │ 6                            │                                                 │
# │    96 │ Peters et al. (2018b)        │                                                 │
# │    97 │ Melamud et al. (2016)        │                                                 │
# │    98 │ Sang and De Meulder, 2003)   │                                                 │
# │    99 │ 7                            │                                                 │
# │   100 │ (Hendrycks and Gimpel, 2016) │                                                 │
# │   101 │ 13                           │                                                 │
# │   102 │ BERT, ELMo ,and              │                                                 │
# │   103 │ 3                            │                                                 │
# │   104 │ 4                            │                                                 │
# │   105 │ Wang et al. (2018a)          │                                                 │
# │   106 │ (Williams et al., 2018)      │                                                 │
# │   107 │ (Rajpurkar et al., 2016)     │                                                 │
# │   108 │ (Wang et al., 2018a          │                                                 │
# │   109 │ (Socher et al., 2013)        │                                                 │
# │   110 │ (Warstadt et al., 2018)      │                                                 │
# │   111 │ (Cer et al., 2017)           │                                                 │
# │   112 │ (Dolan and Brockett, 2005)   │                                                 │
# │   113 │ (Bentivogli et al., 2009     │                                                 │
# │   114 │ (Levesque et al., 2011)      │                                                 │
# │   115 │ 8                            │                                                 │
# │   116 │ Yu et al. (2018)             │                                                 │
# │   117 │                              │                                                 │
# └───────┴──────────────────────────────┴─────────────────────────────────────────────────┘
#                           File: Transformers
# ┏━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Index ┃ Links Refs ┃ Links Html                                    ┃
# ┡━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │     1 │ [13]       │ https://github.com/ tensorflow/tensor2tensor. │
# │     2 │ [7]        │                                               │
# │     3 │ [35,       │                                               │
# │     4 │ 2,         │                                               │
# │     5 │ 5]         │                                               │
# │     6 │ [38,       │                                               │
# │     7 │ 24,        │                                               │
# │     8 │ 15]        │                                               │
# │     9 │ [21]       │                                               │
# │    10 │ [32]       │                                               │
# │    11 │ [2,        │                                               │
# │    12 │ 19]        │                                               │
# │    13 │ [27]       │                                               │
# │    14 │ [16]       │                                               │
# │    15 │ [18]       │                                               │
# │    16 │ [9]        │                                               │
# │    17 │ [12]       │                                               │
# │    18 │ [4,        │                                               │
# │    19 │ 27,        │                                               │
# │    20 │ 28,        │                                               │
# │    21 │ 22]        │                                               │
# │    22 │ [34]       │                                               │
# │    23 │ [17,       │                                               │
# │    24 │ 18]        │                                               │
# │    25 │ [9]        │                                               │
# │    26 │ [5,        │                                               │
# │    27 │ 2,         │                                               │
# │    28 │ 35]        │                                               │
# │    29 │ [10]       │                                               │
# │    30 │ 1          │                                               │
# │    31 │ [11]       │                                               │
# │    32 │ [1]        │                                               │
# │    33 │ 2          │                                               │
# │    34 │ [2]        │                                               │
# │    35 │ [3]        │                                               │
# │    36 │ 2          │                                               │
# │    37 │ [38,       │                                               │
# │    38 │ 2,         │                                               │
# │    39 │ 9]         │                                               │
# │    40 │ 2          │                                               │
# │    41 │ [30]       │                                               │
# │    42 │ 1          │                                               │
# │    43 │ [9]        │                                               │
# │    44 │ [9]        │                                               │
# │    45 │ 3          │                                               │
# │    46 │ [12]       │                                               │
# │    47 │ 1          │                                               │
# │    48 │ [38]       │                                               │
# │    49 │ [31]       │                                               │
# │    50 │ [18]       │                                               │
# │    51 │ [6]        │                                               │
# │    52 │ [3]        │                                               │
# │    53 │ [38]       │                                               │
# │    54 │ 3          │                                               │
# │    55 │ [20]       │                                               │
# │    56 │ [33]       │                                               │
# │    57 │ [36]       │                                               │
# │    58 │ 2          │                                               │
# │    59 │ 3          │                                               │
# │    60 │ [38]       │                                               │
# │    61 │ [38]       │                                               │
# │    62 │ 3          │                                               │
# │    63 │ 3          │                                               │
# │    64 │ 3          │                                               │
# │    65 │ [9]        │                                               │
# │    66 │ [37]       │                                               │
# │    67 │ [25]       │                                               │
# │    68 │ [37]       │                                               │
# │    69 │ 4          │                                               │
# │    70 │ [8]        │                                               │
# │    71 │ [37]       │                                               │
# │    72 │ [29]       │                                               │
# │    73 │            │                                               │
# └───────┴────────────┴───────────────────────────────────────────────┘
